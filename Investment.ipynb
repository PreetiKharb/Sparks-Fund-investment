# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# ### Load data and Helper methods

# %%
# Download csvs from my drive
# !gdown --id 1f-40Rc7fglPiGXgsSWC87pxmteNS19bS --output companies.csv
# !gdown --id 1gjRSdB9oYTaaFszI729ECh8fAy7WcU2m --output rounds2.csv
# !gdown --id 1OX0D16HMIpOJiSdbCO_G3YC1vCCr8qRK --output mapping.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1f-40Rc7fglPiGXgsSWC87pxmteNS19bS
# To: /content/companies.csv
# 8.96MB [00:00, 41.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1gjRSdB9oYTaaFszI729ECh8fAy7WcU2m
# To: /content/rounds2.csv
# 11.8MB [00:00, 25.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OX0D16HMIpOJiSdbCO_G3YC1vCCr8qRK
# To: /content/mapping.csv
# 100% 23.0k/23.0k [00:00<00:00, 8.50MB/s]

# %%
#Create companies data frame
companies = pd.read_csv('companies.csv', encoding = 'ISO-8859-1')
companies.permalink = companies.permalink.str.encode('ISO-8859-1').str.decode('ascii', 'ignore')

# %%
#Create rounds data frame
rounds = pd.read_csv('rounds2.csv', encoding = 'ISO-8859-1')
rounds.company_permalink = rounds.company_permalink.str.encode('ISO-8859-1').str.decode('ascii', 'ignore')

# %%
#Create sectors data frame
sectors = pd.read_csv('mapping.csv', encoding = 'ISO-8859-1')

# %%
#This function will change the float value to its closest Thousand, Million value.
import math

millnames = ['',' Thousand',' Million',' Billion',' Trillion']

def millify(n):
    n = float(n)
    millidx = max(0,min(len(millnames)-1,
                        int(math.floor(0 if n == 0 else math.log10(abs(n))/3))))

    return '{:.0f}{}'.format(n / 10**(3 * millidx), millnames[millidx])

# %%
#This method will remove outliers
def get_iqr_range(df, col=0):
  if(col != 0):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    iqr = Q3-Q1 
    return Q1, Q3,iqr 
  else:
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    iqr = Q3-Q1 
    return Q1[0], Q3[0],iqr[0]

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ### Get Country list where English is primary or official language

# %%
# Read html tables from the url
# Language wiki page to check is the Primary or Official language is English
dataframe_list = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_territories_where_English_is_an_official_language', flavor='bs4')

# Country code wiki page to check the country_code for countries where it is missing in above page, 
#we will need the country code to verify if the country code present in master_frame have a primary/official lang as English or not.
country_code_list = pd.read_html('https://www.iban.com/country-codes', flavor='bs4')

# %%
# These 3 tables have data about primary language
df1 = dataframe_list[0]
df2 = dataframe_list[1]
df3 = dataframe_list[2]

# Concatenate the above 3 tables to get all the data
english_countries = pd.concat([df1,df2,df3])

# Check the unique Country names
english_countries.Country.unique()
# Out:
# array(['Australia', 'New Zealand[1]', 'United Kingdom', 'United States',
#        'Antigua and Barbuda[2]', 'Bahamas[2]', 'Barbados[3]', 'Belize[4]',
#        'Botswana[4]', 'Burundi[5]', 'Cameroon[2]', 'Canada[2]',
#        'Dominica[2]', 'Eswatini[2]', 'Fiji[2]', 'Gambia[2]', 'Ghana[2]',
#        'Grenada[2]', 'Guyana[6]', 'India[4][7]', 'Ireland[8][9]',
#        'Jamaica[10]', 'Kenya[2]', 'Kiribati[2]', 'Lesotho[2]',
#        'Liberia[2]', 'Malawi[11]', 'Malta[2]', 'Marshall Islands[2]',
#        'Mauritius[2]', 'Micronesia[2]', 'Namibia[2]', 'Nauru[12]',
#        'Nigeria[2][13]', 'Pakistan[2]', 'Palau[4]',
#        'Papua New Guinea[14][15]', 'Philippines[2][16]17', 'Rwanda[2]',
#        'Saint Kitts and Nevis[17]', 'Saint Lucia[2]',
#        'Saint Vincent and the Grenadines[18]', 'Samoa[19]',
#        'Seychelles[2]', 'Sierra Leone[2]', 'Singapore[20][21]',
#        'Solomon Islands[2]', 'South Africa[23]', 'South Sudan[24]',
#        'Sudan[2]', 'Tanzania[2]', 'Tonga[25]', 'Trinidad and Tobago[2]',
#        'Tuvalu[4]', 'Uganda[2]', 'Vanuatu[27]', 'Zambia[2]',
#        'Zimbabwe[2]', 'Bahrain[28][29]', 'Bangladesh[30]', 'Brunei[31]',
#        'Cambodia[32]', 'Cyprus[33]', 'Eritrea[2]', 'Ethiopia[2]',
#        'Israel[34][35][36]', 'Jordan[37]', 'Kuwait[38]', 'Malaysia[39]',
#        'Maldives[40]', 'Myanmar[41]', 'Oman[42]', 'Qatar[43]',
#        'Sri Lanka[44][45]', 'United Arab Emirates[46]'], dtype=object)

# %%
# Clean up the country names as it has [] in some of the values
english_countries.Country = english_countries.Country.apply(lambda x: x.split('[')[0])

# Check the unique Country names after removing []
english_countries.Country.unique()
# Out:
# array(['Australia', 'New Zealand', 'United Kingdom', 'United States',
#        'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Botswana',
#        'Burundi', 'Cameroon', 'Canada', 'Dominica', 'Eswatini', 'Fiji',
#        'Gambia', 'Ghana', 'Grenada', 'Guyana', 'India', 'Ireland',
#        'Jamaica', 'Kenya', 'Kiribati', 'Lesotho', 'Liberia', 'Malawi',
#        'Malta', 'Marshall Islands', 'Mauritius', 'Micronesia', 'Namibia',
#        'Nauru', 'Nigeria', 'Pakistan', 'Palau', 'Papua New Guinea',
#        'Philippines', 'Rwanda', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'Seychelles',
#        'Sierra Leone', 'Singapore', 'Solomon Islands', 'South Africa',
#        'South Sudan', 'Sudan', 'Tanzania', 'Tonga', 'Trinidad and Tobago',
#        'Tuvalu', 'Uganda', 'Vanuatu', 'Zambia', 'Zimbabwe', 'Bahrain',
#        'Bangladesh', 'Brunei', 'Cambodia', 'Cyprus', 'Eritrea',
#        'Ethiopia', 'Israel', 'Jordan', 'Kuwait', 'Malaysia', 'Maldives',
#        'Myanmar', 'Oman', 'Qatar', 'Sri Lanka', 'United Arab Emirates'],
#       dtype=object)

# %%
# Drop the unecessary columns and set column names
english_countries.drop(['No.','Region','Population','Population1'], axis=1, inplace=True)
english_countries.columns = ['Country', 'country_code', 'Primary_English']
english_countries.head()
# Out:
#                Country country_code Primary_English
# 0            Australia          AUS             Yes
# 1          New Zealand          NZL             Yes
# 2       United Kingdom          GBR             Yes
# 3        United States          USA             Yes
# 0  Antigua and Barbuda          ATG             Yes

# %%
# As we can see there are countries in the english_countries dataframe which do not have country code present we will get country code from country_codes df
# We need country code as companies.csv have country_code and to check if the country has primary or official language as English 
# we will need to map the master_frame df with english_countries df.
country_codes = country_code_list[0]

# %%
# Drop unecessary columns
country_codes.drop(['Alpha-2 code','Numeric'], axis=1, inplace=True)

# Rename columns 
country_codes.columns = ['Country', 'country_code']
country_codes.head()
# Out:
#           Country country_code
# 0     Afghanistan          AFG
# 1   Åland Islands          ALA
# 2         Albania          ALB
# 3         Algeria          DZA
# 4  American Samoa          ASM

# %%
# There are some country_code as NAN, but we have data for those country code in master_frame data frame, so will need to get data for these
english_countries = pd.merge(english_countries,
                 country_codes, on='Country',how='left')

# %%
# Fill the NANs in country code with the data from country list
english_countries.country_code_x.fillna(english_countries.country_code_y, inplace=True)

# Drop the merged columns with country code.
english_countries.drop(['country_code_y'], axis=1, inplace=True)

#Change column names to make sense
english_countries.columns = ['Country', 'country_code', 'Primary_English']

#Drop NANs
english_countries.dropna(subset=['country_code'], inplace=True)

# %%
# Check all the status for is Primary_English, this we will use in next step to filter countries where primary or official language is not english
english_countries.Primary_English.unique()
# Out:
# array(['Yes', 'No', 'Yes (except Quebec, northern New Brunswick)',
#        'Yes (used as lingua franca, mostly and widely spoken, educational, commerce, and government)',
#        'Yes (used as lingua franca)',
#        'Yes (except for small French Creole population)',
#        'No (but official and educational)', 'Yes (Irish is co-official)',
#        'Yes (in business and education)',
#        'No (but official and in business / education)',
#        'No (used as lingua franca)', 'No (but widely spoken)',
#        'Yes (used as lingua franca, mostly and widely spoken, and educational)',
#        'Yes (and official, educational and lingua franca in formal economy)',
#        'No (but official and educational)[26]', nan], dtype=object)

# %%
# If the Primary_English is NAN that means the official language is not english hence we will set the NANs to No
english_countries.Primary_English.fillna('No', inplace=True)

# Drop No, No (used as lingua franca), No (but widely spoken) as these means that English is not there Primary or Official language
english_countries = english_countries[~(english_countries.Primary_English.isin(['No', 'No (used as lingua franca)', 'No (but widely spoken)']))]
english_countries.head()
# Out:
#                Country country_code Primary_English
# 0            Australia          AUS             Yes
# 1          New Zealand          NZL             Yes
# 2       United Kingdom          GBR             Yes
# 3        United States          USA             Yes
# 4  Antigua and Barbuda          ATG             Yes

# %%
# Verify if any NANs in country_code
english_countries[english_countries['country_code'].isna()].country_code
# Out:
# Series([], Name: country_code, dtype: object)

# %%
# We will use this list to filter the data for investment as Sparks Fund only wants to invest only in English-speaking countries because of the ease of communication with the companies it would invest in
english_countries_list = english_countries['country_code'].tolist()

# %%
str(english_countries_list)
# Out:
# "['AUS', 'NZL', 'GBR', 'USA', 'ATG', 'BHS', 'BRB', 'BLZ', 'CAN', 'DMA', 'FJI', 'GHA', 'GRD', 'GUY', 'IND', 'IRL', 'JAM', 'KEN', 'LBR', 'MLT', 'NGA', 'PAK', 'PNG', 'PHL', 'RWA', 'KNA', 'LCA', 'VCT', 'SLE', 'SGP', 'ZAF', 'TTO', 'UGA']"

# %% [markdown]
# ### Companies data

# %%
companies.head(10)
# Out:
#                              permalink  ...  founded_at
# 0                  /Organization/-Fame  ...         NaN
# 1               /Organization/-Qounter  ...  04-09-2014
# 2  /Organization/-The-One-Of-Them-Inc-  ...         NaN
# 3                /Organization/0-6-Com  ...  01-01-2007
# 4       /Organization/004-Technologies  ...  01-01-2010
# 5     /Organization/01Games-Technology  ...         NaN
# 6  /Organization/0Ndine-Biomedical-Inc  ...  01-01-1997
# 7                 /Organization/0Xdata  ...  01-01-2011
# 8                      /Organization/1  ...  01-08-2011
# 9            /Organization/1-2-3-Listo  ...  01-01-2012
#
# [10 rows x 10 columns]

# %%
#Check for the columns and row size for the dataframe
companies.shape
# Out:
# (66368, 10)

# %%
#Check the row size for the permalink column
companies.permalink.shape
# Out:
# (66368,)

# %%
#Check number of null values in permalink col
companies.permalink.isnull().sum()
# Out:
# 0

# %%
#By looking at data i can see different casing has been used, to avoid mistake just convert the column to upper case
#We will do the same for rounds company_permalink column
companies.permalink = companies.permalink.apply(lambda x: x.upper())

# %% [markdown]
# How many unique companies are present in companies?

# %%
companies.permalink.nunique()
# Out:
# 66368

# %% [markdown]
# ### Rounds data

# %%
rounds.head()
# Out:
#                      company_permalink  ... raised_amount_usd
# 0                  /organization/-fame  ...      10000000.000
# 1               /ORGANIZATION/-QOUNTER  ...               nan
# 2               /organization/-qounter  ...        700000.000
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  ...       3406878.000
# 4                /organization/0-6-com  ...       2000000.000
#
# [5 rows x 6 columns]

# %%
#By looking at data i can see different casing has been used, to avoid mistake just convert the column to upper case
#We have done the same for companies permalink column
rounds.company_permalink = rounds.company_permalink.apply(lambda x: x.upper())

# %%
#Check for number of rows and columns in the dataframe
rounds.shape
# Out:
# (114949, 6)

# %%
#Check number of null values in company_permalink col
rounds.company_permalink.isnull().sum()
# Out:
# 0

# %% [markdown]
# How many unique companies are present in rounds2?

# %%
rounds.company_permalink.nunique()
# Out:
# 66368

# %%
# verifying the list of entities that are there in rounds but not in companies
print(len(rounds.loc[~rounds['company_permalink'].isin(companies['permalink']), :]))
# Out:
# 0

# %% [markdown]
# ### Master dataframe

# %%
master_frame = pd.merge(rounds,
                 companies, left_on='company_permalink',right_on='permalink',how='left')

# %%
master_frame.head()
# Out:
#                      company_permalink  ...  founded_at
# 0                  /ORGANIZATION/-FAME  ...         NaN
# 1               /ORGANIZATION/-QOUNTER  ...  04-09-2014
# 2               /ORGANIZATION/-QOUNTER  ...  04-09-2014
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  ...         NaN
# 4                /ORGANIZATION/0-6-COM  ...  01-01-2007
#
# [5 rows x 16 columns]

# %%
master_frame['permalink'].isnull().sum()
# Out:
# 0

# %%
# Number of observations in master_frame df
master_frame.company_permalink.isnull().value_counts()
# Out:
# False    114949
# Name: company_permalink, dtype: int64

# %%
# Drop the columns we don't need
master_frame.drop(['funding_round_code', 'homepage_url','status','state_code','region','city','founded_at'], axis=1, inplace=True)

# %%
# Are there any null values
master_frame.isnull().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funded_at                      0
# raised_amount_usd          19990
# permalink                      0
# name                           1
# category_list               3410
# country_code                8678
# dtype: int64

# %%
# Remove null from category list and country code column
master_frame.dropna(subset=['category_list','country_code','raised_amount_usd','name'], inplace=True)

# %%
# After dropping the columns do we still have missing values?
master_frame.isnull().sum()
# Out:
# company_permalink          0
# funding_round_permalink    0
# funding_round_type         0
# funded_at                  0
# raised_amount_usd          0
# permalink                  0
# name                       0
# category_list              0
# country_code               0
# dtype: int64

# %%
#As we are only interested in below 4 investment type, get the data only for those
master_frame = master_frame[master_frame.funding_round_type.isin(['venture','seed','angel','private_equity'])]

# %%
master_frame.shape
# Out:
# (75123, 9)

# %%
# Considering the constraints of Sparks Fund, that Sparks Fund only wants to invest only in English-speaking countries because of the ease of communication with the companies it would invest in
master_frame = master_frame[master_frame['country_code'].isin(english_countries_list)]

# %%
master_frame.shape
# Out:
# (61300, 9)

# %%
master_frame.country_code.unique()
# Out:
# array(['IND', 'USA', 'CAN', 'GBR', 'AUS', 'IRL', 'SGP', 'NGA', 'NZL',
#        'KEN', 'ZAF', 'PHL', 'UGA', 'PAK', 'GHA', 'BRB', 'TTO', 'MLT',
#        'JAM', 'KNA', 'RWA', 'DMA', 'GRD'], dtype=object)

# %%
# Considering the constraints of Spark Funds, that spark fund only want to invest between 5 to 15 million, filter out the rest data
master_frame = master_frame[((master_frame['raised_amount_usd']>5000000) & (master_frame['raised_amount_usd']<15000000))]

# %%
master_frame.shape
# Out:
# (11810, 9)

# %%
master_frame.funding_round_type.value_counts()
# Out:
# venture           11353
# private_equity      302
# seed                119
# angel                36
# Name: funding_round_type, dtype: int64

# %%
master_frame.groupby(by='funding_round_type')['raised_amount_usd'].describe()
# Out:
#                        count        mean  ...          75%          max
# funding_round_type                        ...
# angel                 36.000 7484446.917  ...  8616911.000 13000000.000
# private_equity       302.000 9294675.977  ... 11404500.000 14999999.000
# seed                 119.000 6964385.613  ...  7602340.000 13000000.000
# venture            11353.000 8893183.449  ... 10540450.000 14999999.000
#
# [4 rows x 8 columns]

# %%
master_frame.groupby(by='funding_round_type')['raised_amount_usd'].agg(['sum'])
# Out:
#                                 sum
# funding_round_type
# angel                 269440089.000
# private_equity       2806992145.000
# seed                  828761888.000
# venture            100964311691.000

# %%
master_frame.funding_round_type.isnull().value_counts()
# Out:
# False    11810
# Name: funding_round_type, dtype: int64

# %%
master_frame.raised_amount_usd.isnull().value_counts()
# Out:
# False    11810
# Name: raised_amount_usd, dtype: int64

# %%
master_frame.groupby(by='funding_round_type')['raised_amount_usd'].sum().sort_values(ascending=False)
# Out:
# funding_round_type
# venture          100964311691.000
# private_equity     2806992145.000
# seed                828761888.000
# angel               269440089.000
# Name: raised_amount_usd, dtype: float64

# %%
master_frame.funding_round_type.value_counts()
# Out:
# venture           11353
# private_equity      302
# seed                119
# angel                36
# Name: funding_round_type, dtype: int64

# %%
master_mean_df = master_frame.pivot_table('raised_amount_usd', 'funding_round_type', aggfunc='mean')['raised_amount_usd'].sort_values(ascending=False)
master_median_df = master_frame.pivot_table('raised_amount_usd', 'funding_round_type', aggfunc='median')['raised_amount_usd'].sort_values(ascending=False)
master_sum_df = master_frame.pivot_table('raised_amount_usd', 'funding_round_type', aggfunc='sum')['raised_amount_usd'].sort_values(ascending=False)
master_count_df = master_frame.pivot_table('raised_amount_usd', 'funding_round_type', aggfunc='count')['raised_amount_usd'].sort_values(ascending=False)

# %%
# Lets have a look what can we understand from data, 
fig = make_subplots(1,4)
fig.add_trace(go.Bar(name='Number of investments for each investment type', x=master_count_df.index, y=master_count_df, marker_color = px.colors.qualitative.Plotly[0]), row=1, col=1)
fig.add_trace(go.Bar(name='Sum of amount for the investments for each investment type', x=master_sum_df.index, y=master_sum_df, marker_color = px.colors.qualitative.Plotly[1]), row=1, col=2)
fig.add_trace(go.Bar(name='Average Mean amount of the investments for each investment type', x=master_mean_df.index, y=master_mean_df, marker_color = px.colors.qualitative.Plotly[2]), row=1, col=3)
fig.add_trace(go.Bar(name='Average Median amount of the investments for each investment type', x=master_mean_df.index, y=master_mean_df, marker_color = px.colors.qualitative.Plotly[3]), row=1, col=4)
fig.update_layout(title=dict(text='Number of investments, Sum of amount of investments, Average mean and median of the amount invested for each investment type'), barmode='stack')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f8ff48d7-3b52-4417-9af3-e22fdcb21638" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f8ff48d7-3b52-4417-9af3-e22fdcb21638")) {
#                     Plotly.newPlot(
#                         'f8ff48d7-3b52-4417-9af3-e22fdcb21638',
#                         [{"marker": {"color": "#636EFA"}, "name": "Number of investments for each investment type", "type": "bar", "x": ["venture", "private_equity", "seed", "angel"], "xaxis": "x", "y": [11353, 302, 119, 36], "yaxis": "y"}, {"marker": {"color": "#EF553B"}, "name": "Sum of amount for the investments for each investment type", "type": "bar", "x": ["venture", "private_equity", "seed", "angel"], "xaxis": "x2", "y": [100964311691.0, 2806992145.0, 828761888.0, 269440089.0], "yaxis": "y2"}, {"marker": {"color": "#00CC96"}, "name": "Average Mean amount of the investments for each investment type", "type": "bar", "x": ["private_equity", "venture", "angel", "seed"], "xaxis": "x3", "y": [9294675.976821192, 8893183.44851581, 7484446.916666667, 6964385.613445378], "yaxis": "y3"}, {"marker": {"color": "#AB63FA"}, "name": "Average Median amount of the investments for each investment type", "type": "bar", "x": ["private_equity", "venture", "angel", "seed"], "xaxis": "x4", "y": [9294675.976821192, 8893183.44851581, 7484446.916666667, 6964385.613445378], "yaxis": "y4"}],
#                         {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %%
# From below we can see that most of the investments across different companies has happed for the Venture investment type
fig = px.box(master_frame,x='funding_round_type', y="raised_amount_usd",color="country_code")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9862c559-63ee-4e82-8bcd-e2bf265d7f84" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9862c559-63ee-4e82-8bcd-e2bf265d7f84")) {
#                     Plotly.newPlot(
#                         '9862c559-63ee-4e82-8bcd-e2bf265d7f84',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "country_code=IND<br>funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "country_code=IND", "marker": {"color": "#636efa"}, "name": "country_code=IND", "notched": false, "offsetgroup": "country_code=IND", "orientation": "v", "showlegend": true, "type": "box", "x": ["venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "private_equity", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "private_equity", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "seed", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "private_equity", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "seed", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "private_equity", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "seed", "angel", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "seed", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture"], "x0": " ", "xaxis": "x", "y": [10000000.0, 6369507.0, 6410000.0, 8180000.0, 5740000.0, 5500000.0, 7500000.0, 8000000.0, 10000000.0, 12000000.0, 12000000.0, 8600000.0, 6300000.0, 5400000.0, 5530000.0, 10000000.0, 10000000.0, 13600000.0, 8600000.0, 10000000.0, 9600000.0, 6000000.0, 13000000.0, 10000000.0, 6100000.0, 9250000.0, 11750000.0, 10000000.0, 6500000.0, 6500000.0, 13000000.0, 10000000.0, 6000000.0, 7000000.0, 9500000.0, 9000000.0, 10000000.0, 6000000.0, 6000000.0, 5500000.0, 8000000.0, 5400000.0, 7500000.0, 7500000.0, 6000000.0, 10400000.0, 7500000.0, 6000000.0, 6000000.0, 10000000.0, 12000000.0, 7003500.0, 6500000.0, 6000000.0, 9000000.0, 9760000.0, 6000000.0, 6000000.0, 9350000.0, 5400000.0, 5500000.0, 6000000.0, 10000000.0, 5500000.0, 6000000.0, 10300000.0, 10040000.0, 7500000.0, 10000000.0, 8620000.0, 140000 ...

# %%
fig = go.Figure(data=[
    go.Bar(name='Count of investments for each investment type',x=master_count_df.index, y=master_count_df),
    go.Bar(name='Sum of investments for each investment type',x=master_sum_df.index, y=master_sum_df),
    go.Bar(name='Mean of investments for each investment type',x=master_mean_df.index, y=master_mean_df)
])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2cbc5f3c-bd77-4a79-b782-ad5705649fd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2cbc5f3c-bd77-4a79-b782-ad5705649fd4")) {
#                     Plotly.newPlot(
#                         '2cbc5f3c-bd77-4a79-b782-ad5705649fd4',
#                         [{"name": "Count of investments for each investment type", "type": "bar", "x": ["venture", "private_equity", "seed", "angel"], "y": [11353, 302, 119, 36]}, {"name": "Sum of investments for each investment type", "type": "bar", "x": ["venture", "private_equity", "seed", "angel"], "y": [100964311691.0, 2806992145.0, 828761888.0, 269440089.0]}, {"name": "Mean of investments for each investment type", "type": "bar", "x": ["private_equity", "venture", "angel", "seed"], "y": [9294675.976821192, 8893183.44851581, 7484446.916666667, 6964385.613445378]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
fig = px.box(master_frame,x='funding_round_type', y="raised_amount_usd", color='funding_round_type')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4f0f5ee-548b-448e-bb3e-398d6f976678" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4f0f5ee-548b-448e-bb3e-398d6f976678")) {
#                     Plotly.newPlot(
#                         'f4f0f5ee-548b-448e-bb3e-398d6f976678',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "funding_round_type=venture", "marker": {"color": "#636efa"}, "name": "funding_round_type=venture", "notched": false, "offsetgroup": "funding_round_type=venture", "orientation": "v", "showlegend": true, "type": "box", "x": ["venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture" ...

# %%
master_frame.groupby(by='funding_round_type')['raised_amount_usd'].agg(['describe'])
# Out:
#                     describe              ...
#                        count        mean  ...          75%          max
# funding_round_type                        ...
# angel                 36.000 7484446.917  ...  8616911.000 13000000.000
# private_equity       302.000 9294675.977  ... 11404500.000 14999999.000
# seed                 119.000 6964385.613  ...  7602340.000 13000000.000
# venture            11353.000 8893183.449  ... 10540450.000 14999999.000
#
# [4 rows x 8 columns]

# %%
master_frame.groupby(by='funding_round_type')['raised_amount_usd'].agg(['sum'])
# Out:
#                                 sum
# funding_round_type
# angel                 269440089.000
# private_equity       2806992145.000
# seed                  828761888.000
# venture            100964311691.000

# %% [markdown]
# ### Q1 Representative funding amount of venture type

# %%
venture_df = master_frame[master_frame.funding_round_type=='venture']
print('The raised amount for venture funding is ', venture_df.raised_amount_usd.mean())
millify(venture_df.raised_amount_usd.mean())
# Out:
# The raised amount for venture funding is  8893183.44851581
# '9 Million'

# %%
# look if there are any outliers
fig = px.box(venture_df,x='funding_round_type', y="raised_amount_usd")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b481fab4-b05f-40cb-b22e-4521a44d7a67" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b481fab4-b05f-40cb-b22e-4521a44d7a67")) {
#                     Plotly.newPlot(
#                         'b481fab4-b05f-40cb-b22e-4521a44d7a67',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture", "venture" ...

# %%
venture_df.raised_amount_usd.describe()
# Out:
# count      11353.000
# mean     8893183.449
# std      2535430.050
# min      5000001.000
# 25%      6700000.000
# 50%      8500000.000
# 75%     10540450.000
# max     14999999.000
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# ### Q2 Representative funding amount of angel type

# %%
angel_df = master_frame[master_frame.funding_round_type=='angel']
print('The raised amount for angel funding is ', angel_df.raised_amount_usd.mean())
millify(angel_df.raised_amount_usd.mean())
# Out:
# The raised amount for angel funding is  7484446.916666667
# '7 Million'

# %%
# look if there are any outliers
fig = px.box(angel_df,x='funding_round_type', y="raised_amount_usd")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="23045698-4435-44b5-96b2-1cd597cfa3d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23045698-4435-44b5-96b2-1cd597cfa3d3")) {
#                     Plotly.newPlot(
#                         '23045698-4435-44b5-96b2-1cd597cfa3d3',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel", "angel"], "x0": " ", "xaxis": "x", "y": [7000000.0, 10000000.0, 12500000.0, 5300000.0, 5650000.0, 7700000.0, 6000000.0, 5150000.0, 10000000.0, 7100000.0, 6500000.0, 7405253.0, 5800000.0, 6000000.0, 5650000.0, 9000000.0, 8967644.0, 6000000.0, 12000000.0, 8500000.0, 8000000.0, 6100000.0, 6750000.0, 7000000.0, 5600000.0, 5187192.0, 10000000.0, 7000000.0, 5020000.0, 10000000.0, 6400000.0, 7500000.0, 7000000.0, 5810000.0, 6850000.0, 13000000.0], "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %%
angel_df.raised_amount_usd.describe()
# Out:
# count         36.000
# mean     7484446.917
# std      2120123.503
# min      5020000.000
# 25%      5952500.000
# 50%      7000000.000
# 75%      8616911.000
# max     13000000.000
# Name: raised_amount_usd, dtype: float64

# %%
millify(angel_df.raised_amount_usd.mean())
# Out:
# '7 Million'

# %% [markdown]
# ### Q3 Representative funding amount of seed type

# %%
seed_df = master_frame[master_frame.funding_round_type=='seed']
print('The raised amount for seed funding is ', seed_df.raised_amount_usd.mean())
millify(seed_df.raised_amount_usd.mean())
# Out:
# The raised amount for seed funding is  6964385.613445378
# '7 Million'

# %%
# look if there are any outliers
fig = px.box(seed_df,x='funding_round_type', y="raised_amount_usd")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="202f63ec-30dc-4fbd-b01e-3a31e83cfa6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("202f63ec-30dc-4fbd-b01e-3a31e83cfa6a")) {
#                     Plotly.newPlot(
#                         '202f63ec-30dc-4fbd-b01e-3a31e83cfa6a',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed"], "x0": " ", "xaxis": "x", "y": [5100000.0, 9300000.0, 6300000.0, 7356643.0, 7761532.0, 6000000.0, 7000000.0, 6300000.0, 6000000.0, 5700000.0, 10000000.0, 5400000.0, 5987939.0, 6000000.0, 6000000.0, 6000000.0, 5906547.0, 6300000.0, 8000000.0, 6272598.0, 6700000.0, 5490339.0, 7700000.0, 6280000.0, 5900008.0, 8000000.0, 7500000.0, 9259164.0, 6900000.0, 6500000.0, 7000000.0, 8065397.0, 5250000.0, 10000000.0, 5600000.0, 7000000.0, 5651295.0, 6200000.0, 12600000.0, 5500000.0, 6100000.0, 6000000.0, 7500000.0, 10000000.0, 5400000.0, 7123470.0, 6000000.0, 8000000.0, 7000000.0, 11000000.0, 10000000.0, 5300000.0, 5800000.0, 5943536.0, 6000000.0, 5800000.0, 5303380.0, 5700000.0, 7100000.0, 6000000.0, 5500000.0, 6000000.0, 5500003.0, 6000000.0, 5150000.0, 6500000.0, 7542005.0, 5500000.0, 7000000.0, 10000000.0, 8532000.0, 12000000.0, 7662675.0, 5399988.0, 5900000.0, 6000000.0, 6100000.0, 10000000.0, 13000000.0, 12500000.0, 6250000.0, 6958200.0, 5200000.0, 5200000.0, 5300000.0, 6475000.0, 10000000.0, 8000000.0, 8000000.0, 6400000.0, 5600000.0, 8700000.0, 6500000.0, 5600000.0, 6000000.0, 6000000.0, 11500000.0, 11500000.0, 6500000.0, 6000000.0, 6300000.0, 5500000.0, 5800000.0, 5100000.0, 6500000.0, 5017863.0, 6006000.0, 5500000.0, 6620000.0, 12000000.0, 6400000.0, 6000000.0, 5700000.0, 5500000.0, 5335323.0, 8500000.0, 9060983.0, 6100000.0, 5500000.0], "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %%
Q1, Q3, IQR = get_iqr_range(seed_df, 'raised_amount_usd')
print(Q1, Q3, IQR)
seed_df2 = seed_df[~((seed_df.raised_amount_usd < (Q1 - 1.5 * IQR)) |(seed_df.raised_amount_usd > (Q3 + 1.5 * IQR)))]
# Out:
# 5750000.0 7602340.0 1852340.0

# %%
# look if there are any outliers
fig = px.box(seed_df2,x='funding_round_type', y="raised_amount_usd")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0c734a98-0cfa-4306-b5ef-1b2f5820bfed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c734a98-0cfa-4306-b5ef-1b2f5820bfed")) {
#                     Plotly.newPlot(
#                         '0c734a98-0cfa-4306-b5ef-1b2f5820bfed',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed", "seed"], "x0": " ", "xaxis": "x", "y": [5100000.0, 9300000.0, 6300000.0, 7356643.0, 7761532.0, 6000000.0, 7000000.0, 6300000.0, 6000000.0, 5700000.0, 10000000.0, 5400000.0, 5987939.0, 6000000.0, 6000000.0, 6000000.0, 5906547.0, 6300000.0, 8000000.0, 6272598.0, 6700000.0, 5490339.0, 7700000.0, 6280000.0, 5900008.0, 8000000.0, 7500000.0, 9259164.0, 6900000.0, 6500000.0, 7000000.0, 8065397.0, 5250000.0, 10000000.0, 5600000.0, 7000000.0, 5651295.0, 6200000.0, 5500000.0, 6100000.0, 6000000.0, 7500000.0, 10000000.0, 5400000.0, 7123470.0, 6000000.0, 8000000.0, 7000000.0, 10000000.0, 5300000.0, 5800000.0, 5943536.0, 6000000.0, 5800000.0, 5303380.0, 5700000.0, 7100000.0, 6000000.0, 5500000.0, 6000000.0, 5500003.0, 6000000.0, 5150000.0, 6500000.0, 7542005.0, 5500000.0, 7000000.0, 10000000.0, 8532000.0, 7662675.0, 5399988.0, 5900000.0, 6000000.0, 6100000.0, 10000000.0, 6250000.0, 6958200.0, 5200000.0, 5200000.0, 5300000.0, 6475000.0, 10000000.0, 8000000.0, 8000000.0, 6400000.0, 5600000.0, 8700000.0, 6500000.0, 5600000.0, 6000000.0, 6000000.0, 6500000.0, 6000000.0, 6300000.0, 5500000.0, 5800000.0, 5100000.0, 6500000.0, 5017863.0, 6006000.0, 5500000.0, 6620000.0, 6400000.0, 6000000.0, 5700000.0, 5500000.0, 5335323.0, 8500000.0, 9060983.0, 6100000.0, 5500000.0], "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %%
seed_df2.raised_amount_usd.describe()
# Out:
# count        111.000
# mean     6600557.550
# std      1308975.295
# min      5017863.000
# 25%      5700000.000
# 50%      6100000.000
# 75%      7050000.000
# max     10000000.000
# Name: raised_amount_usd, dtype: float64

# %%
millify(seed_df2.raised_amount_usd.mean())
# Out:
# '7 Million'

# %% [markdown]
# ### Q4 Representative funding amount of private equity type

# %%
private_equity_df = master_frame[master_frame.funding_round_type=='private_equity']
print('The raised amount for private equity funding is ', private_equity_df.raised_amount_usd.mean())
millify(private_equity_df.raised_amount_usd.mean())
# Out:
# The raised amount for private equity funding is  9294675.976821192
# '9 Million'

# %%
private_equity_df.shape
# Out:
# (302, 9)

# %%
private_equity_df.describe()
# Out:
#        raised_amount_usd
# count            302.000
# mean         9294675.977
# std          2718676.089
# min          5000822.000
# 25%          6771556.250
# 50%          9763022.000
# 75%         11404500.000
# max         14999999.000

# %%
# look if there are any outliers
fig = px.box(private_equity_df,x='funding_round_type', y="raised_amount_usd")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5c6d0c35-d79f-4d11-91a8-dabe5fb6586b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c6d0c35-d79f-4d11-91a8-dabe5fb6586b")) {
#                     Plotly.newPlot(
#                         '5c6d0c35-d79f-4d11-91a8-dabe5fb6586b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "funding_round_type=%{x}<br>raised_amount_usd=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_equity", "private_eq ...

# %%
millify(private_equity_df.raised_amount_usd.mean())
# Out:
# '9 Million'

# %% [markdown]
# ### Country analysis

# %% [markdown]
# #### Creating top 9 for venture investment type

# %%
# Creating a grouped df having countries against the total amount of investments for venture funding type.
top9 = venture_df.groupby(['country_code'])['raised_amount_usd'].sum().sort_values(ascending=False).head(9)
top9 = pd.DataFrame(top9).reset_index()

# %%
top9
# Out:
#   country_code  raised_amount_usd
# 0          USA    89006584223.000
# 1          GBR     4889078691.000
# 2          CAN     3159289960.000
# 3          IND     2174543602.000
# 4          SGP      521143978.000
# 5          IRL      475855587.000
# 6          AUS      441989729.000
# 7          NZL      107672621.000
# 8          NGA       71000000.000

# %%
# A plot showing the top 9 countries against the total amount of investments of venture funding type.
fig = px.bar(top9,x='country_code', y="raised_amount_usd", color='country_code', labels={'country_code':'Country Code', 'raised_amount_usd':'Total Raised Amount'})
fig.update_layout(autosize=False,width=750,height=450,legend=dict(
        x=0.73,
        y=0.99,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
    ))
fig.show() #to check if there are any outliers and i can see that for US  there are some
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="633ffac5-55c7-40c7-838b-18d61f0d8590" class="plotly-graph-div" style="height:450px; width:750px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("633ffac5-55c7-40c7-838b-18d61f0d8590")) {
#                     Plotly.newPlot(
#                         '633ffac5-55c7-40c7-838b-18d61f0d8590',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=USA", "marker": {"color": "#636efa"}, "name": "Country Code=USA", "offsetgroup": "Country Code=USA", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["USA"], "xaxis": "x", "y": [89006584223.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=GBR", "marker": {"color": "#EF553B"}, "name": "Country Code=GBR", "offsetgroup": "Country Code=GBR", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["GBR"], "xaxis": "x", "y": [4889078691.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=CAN", "marker": {"color": "#00cc96"}, "name": "Country Code=CAN", "offsetgroup": "Country Code=CAN", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["CAN"], "xaxis": "x", "y": [3159289960.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=IND", "marker": {"color": "#ab63fa"}, "name": "Country Code=IND", "offsetgroup": "Country Code=IND", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["IND"], "xaxis": "x", "y": [2174543602.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=SGP", "marker": {"color": "#FFA15A"}, "name": "Country Code=SGP", "offsetgroup": "Country Code=SGP", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["SGP"], "xaxis": "x", "y": [521143978.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=IRL", "marker": {"color": "#19d3f3"}, "name": "Country Code=IRL", "offsetgroup": "Country Code=IRL", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["IRL"], "xaxis": "x", "y": [475855587.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=AUS", "marker": {"color": "#FF6692"}, "name": "Country Code=AUS", "offsetgroup": "Country Code=AUS", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["AUS"], "xaxis": "x", "y": [441989729.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=NZL", "marker": {"color": "#B6E880"}, "name": "Country Code=NZL", "offsetgroup": "Country Code=NZL", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["NZL"], "xaxis": "x", "y": [107672621.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=%{x}<br>Total Raised Amount=%{y}", "legendgroup": "Country Code=NGA", "marker": {"color": "#FF97FF"}, "name": "Country Code=NGA", "offsetgroup": "Country Code=NGA", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["NGA"], "xaxis": "x", "y": [71000000.0], "yaxis": "y"}],
#                         {"autosize": false, "barmode": "relative", "height": 450, "legend": {"font": {"color": "black", "family": "sans-serif", "size": 12}, "tracegroupgap": 0, "traceorder": "normal", "x": 0.73, "y": 0.99}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outline

# %%
#Top English-speaking country
print('Top English-speaking country: ',top9.country_code.loc[0])

#Second English-speaking country
print('Second English-speaking country: ',top9.country_code.loc[1])

#Third English-speaking country as CAN
print('Third English-speaking country: ',top9.country_code.loc[2])
# Out:
# Top English-speaking country:  USA
# Second English-speaking country:  GBR
# Third English-speaking country:  CAN

# %%
top9_countries_df = venture_df[venture_df.country_code.isin(top9.country_code)]
top9_countries_df.head()
# Out:
#                    company_permalink  ... country_code
# 0                /ORGANIZATION/-FAME  ...          IND
# 12              /ORGANIZATION/0XDATA  ...          USA
# 103     /ORGANIZATION/128-TECHNOLOGY  ...          USA
# 112  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 113  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
#
# [5 rows x 9 columns]

# %%
pd.DataFrame(top9)
# Out:
#   country_code  raised_amount_usd
# 0          USA    89006584223.000
# 1          GBR     4889078691.000
# 2          CAN     3159289960.000
# 3          IND     2174543602.000
# 4          SGP      521143978.000
# 5          IRL      475855587.000
# 6          AUS      441989729.000
# 7          NZL      107672621.000
# 8          NGA       71000000.000

# %%
type_country_invest_df = top9_countries_df[top9_countries_df.country_code.isin(['USA','GBR','CAN'])]

# %%
type_country_invest_df.reset_index(drop=True, inplace=True)

# %%
type_country_invest_df.head(10)
# Out:
#                  company_permalink  ... country_code
# 0             /ORGANIZATION/0XDATA  ...          USA
# 1     /ORGANIZATION/128-TECHNOLOGY  ...          USA
# 2  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 3  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 4  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 5        /ORGANIZATION/170-SYSTEMS  ...          USA
# 6            /ORGANIZATION/17ZUOYE  ...          USA
# 7         /ORGANIZATION/2080-MEDIA  ...          USA
# 8         /ORGANIZATION/2080-MEDIA  ...          USA
# 9               /ORGANIZATION/21E6  ...          USA
#
# [10 rows x 9 columns]

# %% [markdown]
# ### Sectors

# %%
sectors.head()
# Out:
#    category_list  ...  Social, Finance, Analytics, Advertising
# 0            NaN  ...                                        0
# 1             3D  ...                                        0
# 2    3D Printing  ...                                        0
# 3  3D Technology  ...                                        0
# 4     Accounting  ...                                        1
#
# [5 rows x 10 columns]

# %%
sectors.shape
# Out:
# (688, 10)

# %%
sectors.category_list.nunique()
# Out:
# 687

# %%
sectors.category_list.isnull().sum()
# Out:
# 1

# %%
sectors[sectors.category_list.isnull()]
# Out:
#   category_list  ...  Social, Finance, Analytics, Advertising
# 0           NaN  ...                                        0
#
# [1 rows x 10 columns]

# %%
sectors.dropna(subset=['category_list'], inplace=True)

# %%
sectors.category_list.isnull().sum()
# Out:
# 0

# %%
sectors.category_list = sectors.category_list.replace({'0':'na', '2.na' :'2.0'}, regex=True)
sectors.head()
# Out:
#       category_list  ...  Social, Finance, Analytics, Advertising
# 1                3D  ...                                        0
# 2       3D Printing  ...                                        0
# 3     3D Technology  ...                                        0
# 4        Accounting  ...                                        1
# 5  Active Lifestyle  ...                                        0
#
# [5 rows x 10 columns]

# %%
#Reshaping the mapping dataframe to merge with the master_frame dataframe. Using melt() function to unpivot the table.
sectors = pd.melt(sectors, id_vars =['category_list'], value_vars =['Manufacturing','Automotive & Sports',
                                                              'Cleantech / Semiconductors','Entertainment',
                                                             'Health','News, Search and Messaging','Others',
                                                             'Social, Finance, Analytics, Advertising']) 
sectors = sectors[~(sectors.value == 0)]
sectors = sectors.drop('value', axis = 1)
sectors = sectors.rename(columns = {"variable":"main_sector"})
sectors.head()
# Out:
#          category_list    main_sector
# 0                   3D  Manufacturing
# 1          3D Printing  Manufacturing
# 2        3D Technology  Manufacturing
# 6   Advanced Materials  Manufacturing
# 14         Agriculture  Manufacturing

# %%
type_country_invest_df.shape
# Out:
# (10911, 9)

# %%
type_country_invest_df.head()
# Out:
#                  company_permalink  ... country_code
# 0             /ORGANIZATION/0XDATA  ...          USA
# 1     /ORGANIZATION/128-TECHNOLOGY  ...          USA
# 2  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 3  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 4  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
#
# [5 rows x 9 columns]

# %%
#check if any value has | in it
type_country_invest_df[type_country_invest_df['category_list'].str.find('|')>-1]
# Out:
#                    company_permalink  ... country_code
# 1       /ORGANIZATION/128-TECHNOLOGY  ...          USA
# 6              /ORGANIZATION/17ZUOYE  ...          USA
# 9                 /ORGANIZATION/21E6  ...          USA
# 11             /ORGANIZATION/23ANDME  ...          USA
# 12             /ORGANIZATION/23ANDME  ...          USA
# ...                              ...  ...          ...
# 10898  /ORGANIZATION/ZYGA-TECHNOLOGY  ...          USA
# 10899  /ORGANIZATION/ZYGA-TECHNOLOGY  ...          USA
# 10904            /ORGANIZATION/ZYNGA  ...          USA
# 10905            /ORGANIZATION/ZYNGA  ...          USA
# 10906            /ORGANIZATION/ZYNGA  ...          USA
#
# [5179 rows x 9 columns]

# %%
# Remove | from the values
#type_country_invest_df["category_list"] = type_country_invest_df["category_list"].str.split("|", n = 1, expand = True)[0]

type_country_invest_df.category_list = type_country_invest_df.category_list.apply(lambda x: x.split('|')[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Check if there are still any values present where | are present
type_country_invest_df[type_country_invest_df['category_list'].str.find('|')>-1]
# Out:
# Empty DataFrame
# Columns: [company_permalink, funding_round_permalink, funding_round_type, funded_at, raised_amount_usd, permalink, name, category_list, country_code]
# Index: []

# %%
type_country_invest_df.head()
# Out:
#                  company_permalink  ... country_code
# 0             /ORGANIZATION/0XDATA  ...          USA
# 1     /ORGANIZATION/128-TECHNOLOGY  ...          USA
# 2  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 3  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
# 4  /ORGANIZATION/1366-TECHNOLOGIES  ...          USA
#
# [5 rows x 9 columns]

# %%
type_country_invest_df.category_list.nunique()
# Out:
# 413

# %%
# covert the category_list strings to lower case
sectors.category_list = sectors.category_list.apply(lambda x: x.lower())
type_country_invest_df["category_list"] = type_country_invest_df["category_list"].str.lower()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
venture_countries_sectors_df  = pd.merge(type_country_invest_df,sectors, on='category_list', how='left')

# %%
venture_countries_sectors_df.head()
# Out:
#                  company_permalink  ...                              main_sector
# 0             /ORGANIZATION/0XDATA  ...  Social, Finance, Analytics, Advertising
# 1     /ORGANIZATION/128-TECHNOLOGY  ...                                   Others
# 2  /ORGANIZATION/1366-TECHNOLOGIES  ...                            Manufacturing
# 3  /ORGANIZATION/1366-TECHNOLOGIES  ...                            Manufacturing
# 4  /ORGANIZATION/1366-TECHNOLOGIES  ...                            Manufacturing
#
# [5 rows x 10 columns]

# %%
venture_countries_sectors_df.isnull().sum()
# Out:
# company_permalink          0
# funding_round_permalink    0
# funding_round_type         0
# funded_at                  0
# raised_amount_usd          0
# permalink                  0
# name                       0
# category_list              0
# country_code               0
# main_sector                1
# dtype: int64

# %%
venture_countries_sectors_df.dropna(subset=['main_sector'], inplace=True)

# %%
venture_countries_sectors_df.isnull().sum()
# Out:
# company_permalink          0
# funding_round_permalink    0
# funding_round_type         0
# funded_at                  0
# raised_amount_usd          0
# permalink                  0
# name                       0
# category_list              0
# country_code               0
# main_sector                0
# dtype: int64

# %%
venture_countries_sectors_df.head()
# Out:
#                  company_permalink  ...                              main_sector
# 0             /ORGANIZATION/0XDATA  ...  Social, Finance, Analytics, Advertising
# 1     /ORGANIZATION/128-TECHNOLOGY  ...                                   Others
# 2  /ORGANIZATION/1366-TECHNOLOGIES  ...                            Manufacturing
# 3  /ORGANIZATION/1366-TECHNOLOGIES  ...                            Manufacturing
# 4  /ORGANIZATION/1366-TECHNOLOGIES  ...                            Manufacturing
#
# [5 rows x 10 columns]

# %%
# FT: Venture type, Country: USA
D1 = venture_countries_sectors_df[(venture_countries_sectors_df['country_code'] == 'USA')]
D1_gr = D1[['raised_amount_usd','main_sector']].groupby('main_sector').agg(['sum', 'count']).rename(
    columns={'sum':'Total_amount','count' : 'Total_count'})
D1 = D1.merge(D1_gr, how='left', on ='main_sector')
D1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:643: UserWarning:
#
# merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#                  company_permalink  ... (raised_amount_usd, Total_count)
# 0             /ORGANIZATION/0XDATA  ...                             2216
# 1     /ORGANIZATION/128-TECHNOLOGY  ...                             2423
# 2  /ORGANIZATION/1366-TECHNOLOGIES  ...                              691
# 3  /ORGANIZATION/1366-TECHNOLOGIES  ...                              691
# 4  /ORGANIZATION/1366-TECHNOLOGIES  ...                              691
#
# [5 rows x 12 columns]

# %%
# FT: Venture type, Country: GBR
D2 = venture_countries_sectors_df[(venture_countries_sectors_df['country_code'] == 'GBR')]
D2_gr = D2[['raised_amount_usd','main_sector']].groupby('main_sector').agg(['sum', 'count']).rename(
    columns={'sum':'Total_amount','count' : 'Total_count'})
D2 = D2.merge(D2_gr, how='left', on ='main_sector')
D2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:643: UserWarning:
#
# merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#          company_permalink  ... (raised_amount_usd, Total_count)
# 0  /ORGANIZATION/365SCORES  ...                              118
# 1   /ORGANIZATION/7DIGITAL  ...                               48
# 2   /ORGANIZATION/7DIGITAL  ...                               48
# 3      /ORGANIZATION/90MIN  ...                               48
# 4    /ORGANIZATION/ABCODIA  ...                              126
#
# [5 rows x 12 columns]

# %%
# FT: Venture type, Country: CAN
D3 = venture_countries_sectors_df[(venture_countries_sectors_df['country_code'] == 'CAN')]
D3_gr = D3[['raised_amount_usd','main_sector']].groupby('main_sector').agg(['sum', 'count']).rename(
    columns={'sum':'Total_amount','count' : 'Total_count'})
D3 = D3.merge(D3_gr, how='left', on ='main_sector')
D3.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:643: UserWarning:
#
# merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#                  company_permalink  ... (raised_amount_usd, Total_count)
# 0          /ORGANIZATION/2CATALYZE  ...                               98
# 1  /ORGANIZATION/360INCENTIVES-COM  ...                               98
# 2              /ORGANIZATION/500PX  ...                               40
# 3              /ORGANIZATION/500PX  ...                               40
# 4         /ORGANIZATION/6N-SILICON  ...                               98
#
# [5 rows x 12 columns]

# %%
#Total number of investments (count)
print(D1.raised_amount_usd.count())
print(D2.raised_amount_usd.count())
print(D3.raised_amount_usd.count())
# Out:
# 9983
# 561
# 366

# %%
#Total amount of investment (USD)
print(round(D1.raised_amount_usd.sum(), 2))
print(round(D2.raised_amount_usd.sum(), 2))
print(round(D3.raised_amount_usd.sum(), 2))
# Out:
# 88997097294.0
# 4889078691.0
# 3159289960.0

# %%
#Top sector, second-top, third-top for D1 (based on count of investments)
#Number of investments in the top, second-top, third-top sector in D1
D1_num_investments =pd.DataFrame(D1_gr['raised_amount_usd']['Total_count'].sort_values(ascending=False))
D1_num_investments['country_code'] = 'USA'
D1_num_investments[:3]
# Out:
#                                          Total_count country_code
# main_sector
# Others                                          2423          USA
# Social, Finance, Analytics, Advertising         2216          USA
# Cleantech / Semiconductors                      1991          USA

# %%
#Top sector, second-top, third-top for D2 (based on count of investments)
#Number of investments in the top, second-top, third-top sector in D2
D2_num_investments = pd.DataFrame(D2_gr['raised_amount_usd']['Total_count'].sort_values(ascending=False))
D2_num_investments['country_code'] = 'GBR'
D2_num_investments[:3]
# Out:
#                                          Total_count country_code
# main_sector
# Others                                           129          GBR
# Cleantech / Semiconductors                       126          GBR
# Social, Finance, Analytics, Advertising          118          GBR

# %%
#Top sector, second-top, third-top for D3 (based on count of investments)
#Number of investments in the top, second-top, third-top sector in D3
D3_num_investments = pd.DataFrame(D3_gr['raised_amount_usd']['Total_count'].sort_values(ascending=False))
D3_num_investments['country_code'] = 'CAN'
D3_num_investments[:3]
# Out:
#                                          Total_count country_code
# main_sector
# Others                                            98          CAN
# Cleantech / Semiconductors                        98          CAN
# Social, Finance, Analytics, Advertising           69          CAN

# %%
#For the top sector USA , which company received the highest investment?
company = D1[D1['main_sector']=='Others']
company = company.pivot_table(values = 'raised_amount_usd', index = 'company_permalink', aggfunc = 'sum')
print(company)
company = company.sort_values(by = ['raised_amount_usd'], ascending = False).head()
print(company.head(1))

#For the second top sector USA , which company received the highest investment?
company = D1[D1['main_sector']=='Social, Finance, Analytics, Advertising']
company = company.pivot_table(values = 'raised_amount_usd', index = 'company_permalink', aggfunc = 'sum')
company = company.sort_values(by = 'raised_amount_usd', ascending = False).head()
print(company.head(1))

#Check if the names are same for all the permalinks
print('\n')
print(D1[D1.company_permalink=='/ORGANIZATION/AIRTIGHT-NETWORKS']['name'].unique())
print(D1[D1.company_permalink=='/ORGANIZATION/SHOTSPOTTER']['name'].unique())
# Out:
#                                    raised_amount_usd
# company_permalink
# /ORGANIZATION/128-TECHNOLOGY            11999347.000
# /ORGANIZATION/170-SYSTEMS               14000000.000
# /ORGANIZATION/17ZUOYE                   10000000.000
# /ORGANIZATION/2U                        15100000.000
# /ORGANIZATION/3CROWD-TECHNOLOGIES        6620000.000
# ...                                              ...
# /ORGANIZATION/ZMANDA                     8000000.000
# /ORGANIZATION/ZOLA                      10000000.000
# /ORGANIZATION/ZOZI                      10000000.000
# /ORGANIZATION/ZUDY                       7500000.000
# /ORGANIZATION/ZUNIVERSITY-COM           10000000.000
#
# [1796 rows x 1 columns]
#                                  raised_amount_usd
# company_permalink
# /ORGANIZATION/AIRTIGHT-NETWORKS       54201907.000
#                            raised_amount_usd
# company_permalink
# /ORGANIZATION/SHOTSPOTTER       67933006.000
#
#
# ['AirTight Networks']
# ['SST Inc. (Formerly ShotSpotter)']

# %%
#For the top sector GBR , which company received the highest investment?
company = D2[D2['main_sector']=='Others']
company = company.pivot_table(values = 'raised_amount_usd', index = 'company_permalink', aggfunc = 'sum')
company = company.sort_values(by = 'raised_amount_usd', ascending = False).head()
print(company.head(1))

#For the second top sector GBR , which company received the highest investment?
company = D2[D2['main_sector']=='Cleantech / Semiconductors']
company = company.pivot_table(values = 'raised_amount_usd', index = 'company_permalink', aggfunc = 'sum')
company = company.sort_values(by = 'raised_amount_usd', ascending = False).head()
print(company.head(1))


#Check if the names are same for all the permalinks
print('\n')
print(D2[D2.company_permalink=='/ORGANIZATION/ELECTRIC-CLOUD']['name'].unique())
print(D2[D2.company_permalink=='/ORGANIZATION/EUSA-PHARMA']['name'].unique())
# Out:
#                               raised_amount_usd
# company_permalink
# /ORGANIZATION/ELECTRIC-CLOUD       37000000.000
#                            raised_amount_usd
# company_permalink
# /ORGANIZATION/EUSA-PHARMA       35600000.000
#
#
# ['Electric Cloud']
# ['EUSA Pharma']

# %%
#For the top sector CAN , which company received the highest investment?
company = D3[D3['main_sector']=='Cleantech / Semiconductors']
company = company.pivot_table(values = 'raised_amount_usd', index = 'company_permalink', aggfunc = 'sum')
company = company.sort_values(by = 'raised_amount_usd', ascending = False).head()
print(company.head(1))

#For the second top sector CAN , which company received the highest investment?
company = D3[D3['main_sector']=='Others']
company = company.pivot_table(values = 'raised_amount_usd', index = 'company_permalink', aggfunc = 'sum')
company = company.sort_values(by = 'raised_amount_usd', ascending = False).head()
print(company.head(1))

#Check if the names are same for all the permalinks
print('\n')
print(D3[D3.company_permalink=='/ORGANIZATION/FRESCO-MICROCHIP']['name'].unique())
print(D3[D3.company_permalink=='/ORGANIZATION/NEWSTEP']['name'].unique())
# Out:
#                                 raised_amount_usd
# company_permalink
# /ORGANIZATION/FRESCO-MICROCHIP       48000000.000
#                        raised_amount_usd
# company_permalink
# /ORGANIZATION/NEWSTEP       31477853.000
#
#
# ['Fresco Microchip']
# ['NewStep Networks']

# %%
# Concatenate the df having number of investments in each sector for selected countries
top3 = pd.concat([D1_num_investments[:3],D2_num_investments[:3],D3_num_investments[:3]])
top3.reset_index(inplace=True)

# %% [markdown]
# ### Further visualizations

# %%
# A plot showing the number of investments in the top 3 sectors of the top 3 countries
fig = px.bar(y='Total_count', x='country_code', color='main_sector', data_frame=top3, barmode='group',labels={'Total_count':'Number of Investments','country_code':'Country Code',"main_sector": 'Sector'})
fig.update_layout(autosize=False,width=750,height=450,legend=dict(
        x=0.5,
        y=0.99,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1d17d724-f142-4120-a592-082e87fc2185" class="plotly-graph-div" style="height:450px; width:750px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d17d724-f142-4120-a592-082e87fc2185")) {
#                     Plotly.newPlot(
#                         '1d17d724-f142-4120-a592-082e87fc2185',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sector=Others<br>Country Code=%{x}<br>Number of Investments=%{y}", "legendgroup": "Sector=Others", "marker": {"color": "#636efa"}, "name": "Sector=Others", "offsetgroup": "Sector=Others", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["USA", "GBR", "CAN"], "xaxis": "x", "y": [2423, 129, 98], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sector=Social, Finance, Analytics, Advertising<br>Country Code=%{x}<br>Number of Investments=%{y}", "legendgroup": "Sector=Social, Finance, Analytics, Advertising", "marker": {"color": "#EF553B"}, "name": "Sector=Social, Finance, Analytics, Advertising", "offsetgroup": "Sector=Social, Finance, Analytics, Advertising", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["USA", "GBR", "CAN"], "xaxis": "x", "y": [2216, 118, 69], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sector=Cleantech / Semiconductors<br>Country Code=%{x}<br>Number of Investments=%{y}", "legendgroup": "Sector=Cleantech / Semiconductors", "marker": {"color": "#00cc96"}, "name": "Sector=Cleantech / Semiconductors", "offsetgroup": "Sector=Cleantech / Semiconductors", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["USA", "GBR", "CAN"], "xaxis": "x", "y": [1991, 126, 98], "yaxis": "y"}],
#                         {"autosize": false, "barmode": "group", "height": 450, "legend": {"font": {"color": "black", "family": "sans-serif", "size": 12}, "tracegroupgap": 0, "traceorder": "normal", "x": 0.5, "y": 0.99}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorba ...

# %%
fig = px.pie(top3, values='Total_count', names='country_code', title='% Number of investments in top 3 countries')
fig.update_layout(autosize=False,width=450,height=450,legend=dict(
        x=0.95,
        y=0.99,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="03f0d0cd-79b5-4ddf-97d8-2f8bda73d0e0" class="plotly-graph-div" style="height:450px; width:450px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03f0d0cd-79b5-4ddf-97d8-2f8bda73d0e0")) {
#                     Plotly.newPlot(
#                         '03f0d0cd-79b5-4ddf-97d8-2f8bda73d0e0',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "country_code=%{label}<br>Total_count=%{value}", "labels": ["USA", "USA", "USA", "GBR", "GBR", "GBR", "CAN", "CAN", "CAN"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [2423, 2216, 1991, 129, 126, 118, 98, 98, 69]}],
#                         {"autosize": false, "height": 450, "legend": {"font": {"color": "black", "family": "sans-serif", "size": 12}, "tracegroupgap": 0, "traceorder": "normal", "x": 0.95, "y": 0.99}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, " ...

# %%
fig = px.area(top3, x="country_code", y="Total_count", color="main_sector",
	      line_group="country_code", title='% Number of investments in top 3 countries across top 3 sectors')
fig.update_layout(autosize=False,width=700,height=450,legend=dict(
        x=.4,
        y=0.99,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8e004b62-2a87-4ef8-9a27-9763dc6c70ee" class="plotly-graph-div" style="height:450px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e004b62-2a87-4ef8-9a27-9763dc6c70ee")) {
#                     Plotly.newPlot(
#                         '8e004b62-2a87-4ef8-9a27-9763dc6c70ee',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Others<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Others", "line": {"color": "#636efa"}, "mode": "lines", "name": "main_sector=Others", "orientation": "v", "showlegend": true, "stackgroup": "1", "type": "scatter", "x": ["USA"], "xaxis": "x", "y": [2423], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Others<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Others", "line": {"color": "#636efa"}, "mode": "lines", "name": "main_sector=Others", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["GBR"], "xaxis": "x", "y": [129], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Others<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Others", "line": {"color": "#636efa"}, "mode": "lines", "name": "main_sector=Others", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["CAN"], "xaxis": "x", "y": [98], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Social, Finance, Analytics, Advertising<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Social, Finance, Analytics, Advertising", "line": {"color": "#EF553B"}, "mode": "lines", "name": "main_sector=Social, Finance, Analytics, Advertising", "orientation": "v", "showlegend": true, "stackgroup": "1", "type": "scatter", "x": ["USA"], "xaxis": "x", "y": [2216], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Social, Finance, Analytics, Advertising<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Social, Finance, Analytics, Advertising", "line": {"color": "#EF553B"}, "mode": "lines", "name": "main_sector=Social, Finance, Analytics, Advertising", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["GBR"], "xaxis": "x", "y": [118], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Social, Finance, Analytics, Advertising<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Social, Finance, Analytics, Advertising", "line": {"color": "#EF553B"}, "mode": "lines", "name": "main_sector=Social, Finance, Analytics, Advertising", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["CAN"], "xaxis": "x", "y": [69], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Cleantech / Semiconductors<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Cleantech / Semiconductors", "line": {"color": "#00cc96"}, "mode": "lines", "name": "main_sector=Cleantech / Semiconductors", "orientation": "v", "showlegend": true, "stackgroup": "1", "type": "scatter", "x": ["USA"], "xaxis": "x", "y": [1991], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Cleantech / Semiconductors<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Cleantech / Semiconductors", "line": {"color": "#00cc96"}, "mode": "lines", "name": "main_sector=Cleantech / Semiconductors", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["GBR"], "xaxis": "x", "y": [126], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "main_sector=Cleantech / Semiconductors<br>country_code=%{x}<br>Total_count=%{y}", "legendgroup": "main_sector=Cleantech / Semiconductors", "line": {"color": "#00cc96"}, "mode": "lines", "name": "main_sector=Cleantech / Semiconductors", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["CAN"], "xaxis": "x", "y": [98], "yaxis": "y"}],
#                         {"autosize": false, "height": 450, "legend": {"font": {"color": "black", "family": "sans-serif", "size": 12}, "tracegroupgap": 0, "traceorder": "normal", "x": 0.4, "y": 0.99}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar":

# %%
top3
# Out:
#                                main_sector  Total_count country_code
# 0                                   Others         2423          USA
# 1  Social, Finance, Analytics, Advertising         2216          USA
# 2               Cleantech / Semiconductors         1991          USA
# 3                                   Others          129          GBR
# 4               Cleantech / Semiconductors          126          GBR
# 5  Social, Finance, Analytics, Advertising          118          GBR
# 6                                   Others           98          CAN
# 7               Cleantech / Semiconductors           98          CAN
# 8  Social, Finance, Analytics, Advertising           69          CAN
